# %% [markdown]
# #### Amostragem

# %%
# Carregamento da base de dados
import pandas as pd
import numpy as np
import random

# %%
# Base de dados
ds = pd.read_csv('census.csv')
ds.shape
# Out:
# (32561, 15)

# %%
# Visualizando o cabeçalho 
ds.head()
# Out:
#    age          workclass  final-weight   education  education-num  \
# 0   39          State-gov         77516   Bachelors             13
# 1   50   Self-emp-not-inc         83311   Bachelors             13
# 2   38            Private        215646     HS-grad              9
# 3   53            Private        234721        11th              7
# 4   28            Private        338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loos  hour-per-week  native-country  income
# 0          2174             0             40   United-States   <=50K
# 1             0             0             13   United-States   <=50K
# 2             0             0             40   United-States   <=50K
# 3             0             0             40   United-States   <=50K
# 4             0             0             40            Cuba   <=50K

# %%
# Visualizando o final
ds.tail()
# Out:
#        age      workclass  final-weight    education  education-num  \
# 32556   27        Private        257302   Assoc-acdm             12
# 32557   40        Private        154374      HS-grad              9
# 32558   58        Private        151910      HS-grad              9
# 32559   22        Private        201490      HS-grad              9
# 32560   52   Self-emp-inc        287927      HS-grad              9
#
#             marital-status          occupation relationship    race      sex  \
# 32556   Married-civ-spouse        Tech-support         Wife   White   Female
# 32557   Married-civ-spouse   Machine-op-inspct      Husband   White     Male
# 32558              Widowed        Adm-clerical    Unmarried   White   Female
# 32559        Never-married        Adm-clerical    Own-child   White     Male
# 32560   Married-civ-spouse     Exec-managerial         Wife   White   Female
#
#        capital-gain  capital-loos  hour-per-week  native-country  income
# 32556             0             0             38   United-States   <=50K
# 32557             0             0             40   United-States    >50K
# 32558             0             0             40   United-States   <=50K
# 32559             0             0             20   United-States   <=50K
# 32560         15024             0             40   United-States    >50K

# %% [markdown]
# ##### Amostragem Aleatória Simples

# %%
ds_amostra_aleatoria_simples = ds.sample(n=100)
ds_amostra_aleatoria_simples.shape
# Out:
# (100, 15)

# %%
# Visualizando a amostra
ds_amostra_aleatoria_simples.head()
# Out:
#        age     workclass  final-weight      education  education-num  \
# 8673    28             ?        168524      Assoc-voc             11
# 20578   32       Private         26803   Some-college             10
# 8611    49       Private         76482        HS-grad              9
# 10904   39   Federal-gov        209609        HS-grad              9
# 15004   36       Private        211022      Assoc-voc             11
#
#             marital-status          occupation    relationship    race  \
# 8673    Married-civ-spouse                   ?       Own-child   White
# 20578   Married-civ-spouse   Machine-op-inspct         Husband   White
# 8611    Married-civ-spouse        Craft-repair         Husband   White
# 10904   Married-civ-spouse        Adm-clerical         Husband   White
# 15004             Divorced      Prof-specialty   Not-in-family   White
#
#            sex  capital-gain  capital-loos  hour-per-week  native-country  \
# 8673    Female             0             0             40   United-States
# 20578     Male             0             0             84   United-States
# 8611      Male             0             0             40   United-States
# 10904     Male             0             0             50   United-States
# 15004     Male             0             0             40   United-States
#
#        income
# 8673    <=50K
# 20578    >50K
# 8611    <=50K
# 10904   <=50K
# 15004    >50K

# %%
# Criando uma função de amostragem simples
def amostragem_aleatoria_simples(dataset, amostras):
    return dataset.sample(n=amostras)

# %%
# Executando a função
df_amostra_aleatoria_simple = amostragem_aleatoria_simples(ds, 100)
df_amostra_aleatoria_simple.shape
# Out:
# (100, 15)

# %%
# Visualizando o retorno da função
df_amostra_aleatoria_simple.head()
# Out:
#        age   workclass  final-weight      education  education-num  \
# 20774   21     Private         43535   Some-college             10
# 14278   38     Private        146178        HS-grad              9
# 30928   37     Private        150057        HS-grad              9
# 3226    58   Local-gov        310085           10th              6
# 31889   38     Private         65390     Assoc-acdm             12
#
#             marital-status         occupation    relationship    race  \
# 20774        Never-married              Sales   Not-in-family   White
# 14278        Never-married       Craft-repair       Unmarried   Black
# 30928   Married-civ-spouse       Craft-repair         Husband   White
# 3226    Married-civ-spouse   Transport-moving         Husband   White
# 31889   Married-civ-spouse       Craft-repair         Husband   White
#
#            sex  capital-gain  capital-loos  hour-per-week  native-country  \
# 20774   Female             0             0             40   United-States
# 14278   Female             0             0             40   United-States
# 30928     Male             0             0             52   United-States
# 3226      Male             0             0             40   United-States
# 31889     Male             0             0             45   United-States
#
#        income
# 20774   <=50K
# 14278   <=50K
# 30928    >50K
# 3226    <=50K
# 31889   <=50K
